# %%
import pandas as pd
import json

# %% [markdown]
# Verify the path of the all funding csv and the name

# %%
path = '../raw_data/ALL_funding-rounds-09-12-2021.csv'

# %%
data = pd.read_csv(path)

# %%
data
# Out:
#       Unnamed: 0                  Transaction Name  \
# 0              0         Venture Round - IPI GROUP
# 1              1  Venture Round - ANF ​​Immobilier
# 2              2            Seed Round - Implicity
# 3              3          Series A - Hamilton Apps
# 4              4           Venture Round - Precogs
# ...          ...                               ...
# 9473         855       Debt Financing - HarfangLab
# 9474         856            Seed Round - Beanstock
# 9475         857     Venture Round - Loyez Woessen
# 9476         858                  Grant - HelioRec
# 9477         859              Seed Round - Olarchy
#
#                                    Transaction Name URL Organization Name  \
# 0     https://www.crunchbase.com/funding_round/ipi-g...         IPI GROUP
# 1     https://www.crunchbase.com/funding_round/anf-i...  ANF ​​Immobilier
# 2     https://www.crunchbase.com/funding_round/impli...         Implicity
# ...

# %%
path2 = '../raw_data/crunchbase.csv'
data2 = pd.read_csv(path2)
# Out:
# /tmp/ipykernel_54466/2147539871.py:2: DtypeWarning: Columns (4,11,16,17,18,30,31,32,33,36,39,40,41,42) have mixed types. Specify dtype option on import or set low_memory=False.
#   data2 = pd.read_csv(path2)

# %%
data2
# Out:
#                                          _id  \
# 0       ca17699b-2f49-91f4-5863-7216fc07a64e
# 1       792dcc41-3650-4496-68ba-481f52ccd99e
# 2       35d239af-cf06-4f04-9387-64a079b641cd
# 3       bb06c586-aac4-4657-39d1-1e428f3f08da
# 4       99c2b07b-bbf5-dcac-f768-7b905e940c0e
# ...                                      ...
# 311409  a70808ad-93c0-4ad2-b859-699a25c79ed8
# 311410  c3bc2993-9072-419e-99a3-08d51802dfc5
# 311411  8c003064-a0f0-4d79-9ddc-46854a957894
# 311412  1bab4fea-ea50-4bc1-a28a-91d6de49f921
# 311413  137bcfdd-ff15-4bfa-8da9-92b8d3a8d9cd
#
#                                              acquisitions category  \
# 0       [{"_id":"a07f601f-d80e-4f67-8996-7f80726b25b4"...  company
# 1                                                      []  company
# 2                                                      []  company
# 3                                                      []  company
# 4                                                      []  company
# ...
